# %% [markdown]
# # Worksheet 24
#
# Name:  Maria Eusse Henao
# UID: U97793762
#
# ### Topics
#
# - Tuning Neural Networks
#
# ## Tuning Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# 2023-12-07 18:24:29.961866: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 3/3 [==============================] - 1s 41ms/step - loss: 0.7196
# Epoch 2/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7168
# Epoch 3/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7148
# Epoch 4/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7131
# Epoch 5/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.7116
# Epoch 6/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7102
# Epoch 7/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7089
# Epoch 8/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7076
# Epoch 9/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7063
# Epoch 10/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7052
# Epoch 11/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7041
# Epoch 12/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7031
# Epoch 13/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7018
# Epoch 14/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7007
# Epoch 15/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6995
# Epoch 16/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6983
# Epoch 17/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6973
# Epoch 18/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6963
# Epoch 19/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6952
# Epoch 20/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6942
# Epoch 21/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6931
# Epoch 22/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6920
# Epoch 23/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6910
# Epoch 24/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6900
# Epoch 25/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6888
# Epoch 26/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6877
# Epoch 27/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6867
# Epoch 28/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6857
# Epoch 29/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6848
# Epoch 30/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6838
# Epoch 31/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6827
# Epoch 32/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6817
# Epoch 33/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6807
# Epoch 34/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6797
# Epoch 35/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6787
# Epoch 36/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6777
# Epoch 37/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6767
# Epoch 38/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6757
# Epoch 39/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6747
# Epoch 40/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6737
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6728
# Epoch 42/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6718
# Epoch 43/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6708
# Epoch 44/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6698
# Epoch 45/200
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6688
# Epoch 46/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6679
# Epoch 47/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6670
# Epoch 48/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6662
# Epoch 49/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6652
# Epoch 50/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6643
# Epoch 51/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6634
# Epoch 52/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6626
# Epoch 53/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6617
# Epoch 54/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6608
# Epoch 55/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6599
# Epoch 56/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6589
# Epoch 57/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6580
# Epoch 58/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6573
# Epoch 59/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.